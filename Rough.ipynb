# %%
# Importing libraries

from PIL import Image
import numpy as np
import cv2 as cv
import pytesseract
import matplotlib.pyplot as plt

# %%
# display function for image

def display(im_path):
    dpi = 300
    im_data = plt.imread(im_path)

    height, width  = im_data.shape[:2]
    
    figsize = width / float(dpi), height / float(dpi)

    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 2, 2])

    ax.axis('off')

    name = ax.imshow(im_data, cmap='gray')

    plt.show(name)

# %%
gray_data = []
# connverting image from rgb to bw

def grayscale(image):
    return cv.cvtColor(image, cv.COLOR_BGR2GRAY)

# %%
def noise_removal(image):
    import numpy as np
    kernel = np.ones((1, 1), np.uint8)
    image = cv.dilate(image, kernel, iterations=1)
    kernel = np.ones((1, 1), np.uint8)
    image = cv.erode(image, kernel, iterations=1)
    image = cv.morphologyEx(image, cv.MORPH_CLOSE, kernel)
    image = cv.medianBlur(image, 3)
    return (image)

# %% [markdown]
# # Extract Names

# %%
#using re to extract data 
import re
def extract_name(text):
    pattern1 = r"Name\s+([A-Z\s]+)\s"
    pattern2 = r"Name\s+([^\n]+)"
    pattern3 = r"NAME\s+([A-Z\s]+)\s"
    pattern4 = r"NAME\s+([^\n]+)"
    pattern5 = r"Owner\s+([A-Z\s]+)\s"

    # Use the re.search function to search for the pattern in the text
    try:
        match = re.search(pattern1, text)

        # Check if a match is found
        if match:
        # Extract the owner's name using the group() function
            owners_name = match.group(1).strip()
            print(f"Owner's Name 1: {owners_name}")
#         else:
#             print("na 1")
            
    except:
        pass
    
    try:
        match = re.search(pattern2, text)

        # Check if a match is found
        if match:
        # Extract the owner's name using the group() function
            owners_name = match.group(1).strip()
            print(f"Owner's Name 2: {owners_name}")
            
#         else:
#             print("na 2")
    except:
        pass
    
    # Use the re.search function to search for the pattern in the text
    try:
        match = re.search(pattern3, text)

        # Check if a match is found
        if match:
        # Extract the owner's name using the group() function
            owners_name = match.group(1).strip()
            print(f"Owner's Name 3: {owners_name}")
#         else:
#             print("na 3")
            
    except:
        pass
    
    # Use the re.search function to search for the pattern in the text
    try:
        match = re.search(pattern4, text)

        # Check if a match is found
        if match:
        # Extract the owner's name using the group() function
            owners_name = match.group(1).strip()
            print(f"Owner's Name 4: {owners_name}")
#         else:
#             print("na 4")
            
    except:
        pass
    # Use the re.search function to search for the pattern in the text
    try:
        match = re.search(pattern5, text)

        # Check if a match is found
        if match:
        # Extract the owner's name using the group() function
            owners_name = match.group(1).strip()
            print(f"Owner's Name 5: {owners_name}")
#         else:
#             print("na 4")
            
    except:
        pass

# %% [markdown]
# # Extract Engine num

# %%
#using re to extract data 
import re
def extract_engine_no(text):
    pattern1 = r'Engine \s+([A-Z0-9]+)'
    pattern2 = r'Engine No\.\s+([A-Z0-9’]+)'
    pattern3 = r'(?:Engine No\.|Ones No\.|q jam g|6006878)\s*([A-Z0-9]+)'
    pattern4 = r'ENO\.\s+([A-Z0-9’]+)'
    pattern5 = r"Registration No «: (\w+)"
    pattern6 = r"ENO : (\w+)"
    pattern7 = r"Enaine No (\w+)"
    pattern8 = r"Regn\. No\s([A-Z0-9]+)"

    # Search for the engine number using the pattern
    try:
        match = re.search(pattern1, text)

        # Check if a match was found
        if match:
            # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Engine Number1: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern2, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Engine Number2: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern3, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Engine Number3: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern4, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Engine Number4: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern5, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Engine Number5: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern6, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Engine Number6: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern7, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Engine Number7: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern8, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Engine Number8: {engine_number}")
    
    except:
        pass

# %%
for i in range(1,11):
    image_file = "Resources/rc"+ str(i) + ".jpg"
    img = cv.imread(image_file)
    gray_image = grayscale(img)
    cv.imwrite("Resources/gray"+ str(i)+ ".jpg", gray_image)


    no_noise = noise_removal(gray_image)
    cv.imwrite("Resources/no_noise"+ str(i)+ ".jpg", no_noise)

    ocr_res = pytesseract.image_to_string(no_noise, lang='hin+eng', config='--psm 6')
    df = pytesseract.image_to_data(no_noise, lang='hin+eng', config='--psm 6', output_type='data.frame')
    noise = df[df['conf']>-1]['conf'].mean()
    print(i, len(ocr_res))
    
    extract_name(pytesseract.image_to_string(no_noise, lang='hin+eng', config='--psm 6'))
    
    if extract_name(pytesseract.image_to_string(no_noise, lang='hin+eng', config='--psm 6'))==None:
        extract_name(pytesseract.image_to_string(gray_image, lang='hin+eng', config='--psm 6'))
# Out:
# 1 345
# Owner's Name 2: fi ABDUL SALEEM M K
# 2 711
# Owner's Name 5: MOHD AMAAN SHAFI SHEIKH
# Owner's Name 5: MOHD AMAAN SHAFI SHEIKH
# Owner's Name 5: MOHD AMAAN SHAFI SHEIKH
# SOW
# 3 650
# Owner's Name 2: & S.N.MOTORS. BERHAMPORE MSD. BERHAMPORE
# Owner's Name 2: & S.N.MOTORS. BERHAMPORE MSD. BERHAMPORE
# Owner's Name 2: & : S|N.MOTORS. BERHAMPORE MSD, BERHAMPORE. .. -
# 4 288
# Owner's Name 3: SACHINKUMAR
# Owner's Name 4: SACHINKUMAR
# Owner's Name 3: SACHINKUMAR
# Owner's Name 4: SACHINKUMAR
# 5 300
# Owner's Name 1: NIDHIS CHAUHAN
# Owner's Name 2: NIDHIS CHAUHAN —— = fom :
# 6 605
# Owner's Name 1: RAMESH KUMAR VERMA
# Owner's Name 2: RAMESH KUMAR VERMA }
# Owner's Name 1: RAMESH KUMAR VERMA
# Owner's Name 2: RAMESH KUMAR VERMA }
# Owner's Name 1: RAMESH KUMAR VERMA
# Owner's Name 2: RAMESH KUMAR VERMA j
# 7 480
# Owner's Name 1: ANIL KUMAR
# Owner's Name 2: ANIL KUMAR OBERO!
# Owner's Name 1: ANIL KUMAR
# Owner's Name 2: ANIL KUMAR OBERO!
# ...

# %%
for i in range(1,10):
    image_file = "Resources/rc"+ str(i) + ".jpg"
    img = cv.imread(image_file)
    gray_image = grayscale(img)
    cv.imwrite("Resources/gray"+ str(i)+ ".jpg", gray_image)


    no_noise = noise_removal(gray_image)
    cv.imwrite("Resources/no_noise"+ str(i)+ ".jpg", no_noise)

    ocr_res = pytesseract.image_to_string(no_noise, lang='hin+eng', config='--psm 6')
    df = pytesseract.image_to_data(no_noise, lang='hin+eng', config='--psm 6', output_type='data.frame')
    noise = df[df['conf']>-1]['conf'].mean()
    print(i)
#     extract_engine_no(ocr_res)
    extract_engine_no(pytesseract.image_to_string(no_noise, lang='hin+eng', config='--psm 6'))
    
    if extract_engine_no(pytesseract.image_to_string(no_noise, lang='hin+eng', config='--psm 6'))==None:
        extract_engine_no(pytesseract.image_to_string(gray_image, lang='hin+eng', config='--psm 6'))
# Out:
# 1
# Engine Number3: 6006878
# Engine Number3: 6006878
# 2
# Engine Number2: B084
# Engine Number3: B084
# Engine Number2: B084
# Engine Number3: B084
# Engine Number2: B
# Engine Number3: B
# 3
# Engine Number5: WBSBAE0790
# Engine Number5: WBSBAE0790
# 4
# Engine Number6: REVTRNO2JSYKS4
# Engine Number6: REVTRNO2JSYKS4
# Engine Number6: REVTRNO2JSYK5022
# 5
# Engine Number2: JA’2ABFGHO00309
# Engine Number3: JA
# Engine Number2: JA’2ABFGHO00309
# Engine Number3: JA
# 6
# Engine Number2: L5Z304006
# Engine Number3: L5Z304006
# Engine Number2: L5Z304006
# Engine Number3: L5Z304006
# Engine Number2: L5Z
# Engine Number3: L5Z
# 7
# Engine Number7: G4HG6M978I26
# Engine Number7: G4HG6M978I26
# 8
# Engine Number7: JC65E70666795
# Engine Number7: JC65E70666795
# 9
# Engine Number8: D
# Engine Number8: D
# Engine Number8: D

# %% [markdown]
# # Extract Chaisis num

# %%
#using re to extract data 
import re
def extract_chaisis_no(text):
    pattern1 = r'Chassis \s+([A-Z0-9]+)'
    pattern2 = r'Chassis No\.\s+([A-Z0-9’]+)'
    pattern3 = r'(?:Chassis No\.|Ones No\.|q jam g|6006878)\s*([A-Z0-9]+)'
    pattern4 = r'CH NO\.\s+([A-Z0-9’]+)'
    pattern5 = r'Chassis No,\s*Owner\s*\n([A-Z0-9]+)'
    pattern6 = r"CH NO : (\w+)"
    pattern7 = r'Chasis No\s*([\w+]+)'
    pattern8 = r'Chassis No\s*Owner\s*[\n\r]+([A-Z0-9]+)'

    # Search for the engine number using the pattern
    try:
        match = re.search(pattern1, text)

        # Check if a match was found
        if match:
            # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Chasis Number1: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern2, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Chasis Number2: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern3, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Chasis Number3: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern4, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Chasis Number4: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern5, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Chasis Number5: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern6, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Chasis Number6: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern7, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Chasis Number7: {engine_number}")
    
    except:
        pass
    
    try:
        
        match = re.search(pattern8, text)

        # Check if a match was found
        if match:
        # Extract the engine number from the match object
            engine_number = match.group(1)
            print(f"Chasis Number8: {engine_number}")
    
    except:
        pass

# %%
for i in range(1,10):
    image_file = "Resources/rc"+ str(i) + ".jpg"
    img = cv.imread(image_file)
    gray_image = grayscale(img)
    cv.imwrite("Resources/gray"+ str(i)+ ".jpg", gray_image)


    no_noise = noise_removal(gray_image)
    cv.imwrite("Resources/no_noise"+ str(i)+ ".jpg", no_noise)

    ocr_res = pytesseract.image_to_string(no_noise, lang='hin+eng', config='--psm 6')
    df = pytesseract.image_to_data(no_noise, lang='hin+eng', config='--psm 6', output_type='data.frame')
    noise = df[df['conf']>-1]['conf'].mean()
    print(i)
    extract_chaisis_no(pytesseract.image_to_string(no_noise, lang='hin+eng', config='--psm 6'))
    
    if extract_chaisis_no(pytesseract.image_to_string(no_noise, lang='hin+eng', config='--psm 6'))==None:
        extract_chaisis_no(pytesseract.image_to_string(gray_image, lang='hin+eng', config='--psm 6'))
# Out:
# 1
# Chasis Number3: 6006878
# Chasis Number3: 6006878
# Chasis Number2: O
# Chasis Number3: O
# 2
# Chasis Number2: MABMI
# Chasis Number3: MABMI
# 3
# 4
# Chasis Number6: MAT626283HKJ62784
# Chasis Number6: MAT626283HKJ62784
# Chasis Number6: MAT626283HKJ62784
# 5
# 6
# Chasis Number2: MAKDG72GG40028
# Chasis Number3: MAKDG72GG40028
# Chasis Number2: MAKDG72GG40028
# Chasis Number3: MAKDG72GG40028
# 7
# Chasis Number2: MALABSIHREM9S2386
# Chasis Number3: MALABSIHREM9S2386
# 8
# Chasis Number7: ME4JC654JG744490+
# Chasis Number7: ME4JC654JG744490+
# Chasis Number7: ME4JC65JG7444904
# 9

# %%
 #pattern 3  6 7 chasis

# %%
image_file = "Resources/rc9.jpg"
img = cv.imread(image_file)
gray_image = grayscale(img)
cv.imwrite("Resources/gray9.jpg", gray_image)

no_noise = noise_removal(gray_image)
cv.imwrite("Resources/no_noise9.jpg", no_noise)

ocr_res = pytesseract.image_to_string(no_noise, lang='hin+eng', config='--psm 6')
print(ocr_res)
# Out:
# al
# 0 —————
# Governmeiit of West Bengal (9 ®
# Certificate of Registration(Form 23)
# ४ Regn. No Date of Regn Regn Validity
# WB24AEI6I4 §44.0ct-20I5 —2-Oct-2030
# Chassis No Owner ®
# MASL4BUNF2J6422 srno (4)
# Tax upto = No
# 43-Oct-2020 BUF4J95056
# Fuel Used Owner Name
# Soll ? LIP2CK CONSTRUCTION PVT LTD | ॑
# nghend Son/Daughte rite of =
# BHARAT STAGE ya
# Address
# 2, ALGACHA ROAD, KOLKATA, DUMDUM, KOL, -WEST
# BENGAL-700028
# y 4
# Ker q
# > दर
